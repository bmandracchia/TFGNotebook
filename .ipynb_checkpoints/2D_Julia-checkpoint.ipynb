# %% [markdown]
# # Deconvolution Benchmark: Julia

# %% [markdown]
# ---
# ## Setup

# %%
using DeconvOptim, TestImages, Colors, ImageIO, Noise, ImageShow, Images, Plots, BenchmarkTools, FFTW

# %% [markdown]
# ---
# ## Test Image
#
# Una vez importados los paquetes lo que hemos hecho ha sido coger una imagen de prueba, añadirla borrosidad y ruido y hacer la deconvolución en 2D sin regularizar.
# Usaremos la misma PSF para el código en python y el mismo número de iteraciones.

# %%
# Cargar la imagen de prueba
img = load("ImagenPrueba.jpg")
img = Float32.(img)

# Generar la PSF (Point Spread Function)
psf = Float32.(generate_psf(size(img), 30))

# Crear una versión borrosa y ruidosa de la imagen
img_b = conv(img, psf)  # Imagen borrosa
img_n = poisson(img_b, 300)  # Imagen borrosa y ruidosa

# Guardar la imagen borrosa y ruidosa
# save("blurrednoisy_img.jpg", img_b)

# Deconvolución 2D sin regularizador
res_no_reg, o = deconvolution(img_n, psf, regularizer=nothing, iterations=30)

# Medir el tiempo de ejecución de la deconvolución

b = @benchmark  deconvolution(img_n, psf, regularizer=nothing, iterations=30) samples=15 evals=1
# Out:
# BenchmarkTools.Trial: 7 samples with 1 evaluation.
#  Range (min … max):  417.394 ms …    1.123 s  ┊ GC (min … max):  1.42% … 56.47%
#  Time  (median):     652.502 ms               ┊ GC (median):    34.55%
#  Time  (mean ± σ):   659.326 ms ± 239.229 ms  ┊ GC (mean ± σ):  32.00% ± 19.29%
#
#   █  █    █           █     ██                                █
#   █▁▁█▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█ ▁
#   417 ms           Histogram: frequency by time          1.12 s <
#
#  Memory estimate: 172.58 MiB, allocs estimate: 5827.

# %%
# Mostrar los resultados finales junto a la versión original y la versión borrosa
Gray.([img img_n res_no_reg])
# Out:
# 512×1536 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(1.86089f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000140592)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.64848f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.36007f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(3.0692f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(2.70179f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.90547f-8)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.11233f-8)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.9645f-12)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(6.15352f-11)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(9.60635f-10)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(8.64106f-9)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.20433f-9)
#  ⋮                                       ⋱  ⋮
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(1.40127f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.43942f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(7.95591f-8)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.4471f-8)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.89093f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(1.15745f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(3.33067f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(9.85709f-8)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(8.95359f-9)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.05813f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(6.53305f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.23689f-5)

# %%
# Suponemos que psf ya está definida
# Normaliza los valores de la PSF al rango [0, 1]
psf_min = minimum(psf)
psf_max = maximum(psf)
psf_normalized = (psf .- psf_min) ./ (psf_max - psf_min)
psf_gray = Gray.(psf_normalized)  # Convertir a escala de grises

# Centrar la PSF utilizando ifftshift
centered_psf = ifftshift(psf_normalized)
centered_psf_gray = Gray.(centered_psf)  # Convertir a escala de grises

# Guardar la PSF normalizada como una imagen JPEG
# save("psf.jpg", centered_psf_gray)

# Mostrar la PSF centrada
display(centered_psf_gray)
# Out:
# 512×512 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.000105679)  …  Gray{Float32}(9.8664f-5)
#  Gray{Float32}(9.8664f-5)       Gray{Float32}(9.20257f-5)
#  Gray{Float32}(7.96457f-5)      Gray{Float32}(7.40508f-5)
#  Gray{Float32}(5.40083f-5)      Gray{Float32}(4.98856f-5)
#  Gray{Float32}(2.86578f-5)      Gray{Float32}(2.61165f-5)
#  Gray{Float32}(9.73711f-6)   …  Gray{Float32}(8.57321f-6)
#  Gray{Float32}(7.24719f-7)      Gray{Float32}(5.08772f-7)
#  Gray{Float32}(1.57789f-6)      Gray{Float32}(1.79346f-6)
#  Gray{Float32}(9.16101f-6)      Gray{Float32}(9.34885f-6)
#  Gray{Float32}(1.87059f-5)      Gray{Float32}(1.85714f-5)
#  Gray{Float32}(2.56832f-5)   …  Gray{Float32}(2.51401f-5)
#  Gray{Float32}(2.73588f-5)      Gray{Float32}(2.65047f-5)
#  Gray{Float32}(2.34949f-5)      Gray{Float32}(2.25357f-5)
#  ⋮                           ⋱
#  Gray{Float32}(2.34949f-5)   …  Gray{Float32}(2.25357f-5)
#  Gray{Float32}(2.73588f-5)      Gray{Float32}(2.65047f-5)
#  Gray{Float32}(2.56832f-5)      Gray{Float32}(2.51401f-5)
#  Gray{Float32}(1.87059f-5)      Gray{Float32}(1.85714f-5)
#  Gray{Float32}(9.16101f-6)      Gray{Float32}(9.34885f-6)
#  Gray{Float32}(1.57789f-6)   …  Gray{Float32}(1.79346f-6)
#  Gray{Float32}(7.24719f-7)      Gray{Float32}(5.08772f-7)
#  Gray{Float32}(9.73711f-6)      Gray{Float32}(8.57321f-6)
#  Gray{Float32}(2.86578f-5)      Gray{Float32}(2.61165f-5)
#  Gray{Float32}(5.40083f-5)      Gray{Float32}(4.98856f-5)
#  Gray{Float32}(7.96457f-5)   …  Gray{Float32}(7.40508f-5)
#  Gray{Float32}(9.8664f-5)       Gray{Float32}(9.20257f-5)

# %% [markdown]
# Ahora vamos a usar la función richardson_lucy_iterative del módulo deconvoptim.jl sin regularización.

# %%
# Deconvolución iterativa de Richardson-Lucy sin regularizador
restored_img = richardson_lucy_iterative(img_n, psf; regularizer=nothing, iterations=30);

# %%
Gray.([img img_n restored_img])
# Out:
# 512×1536 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000415541)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000429411)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000380736)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000291058)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000196636)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000122828)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(7.53641f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.85023f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(3.4704f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.87245f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(2.79149f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(3.15363f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.02101f-5)
#  ⋮                                       ⋱  ⋮
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(5.23312f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.93594f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(7.21684f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.46843f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(3.59356f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(9.23051f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.25588f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.97014f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(9.68699f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000167079)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000256085)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000348147)

# %%
c = @benchmark richardson_lucy_iterative(img_n, psf; regularizer=nothing, iterations=30) samples=100 evals=1 seconds=60
# Out:
# BenchmarkTools.Trial: 100 samples with 1 evaluation.
#  Range (min … max):   95.578 ms … 146.243 ms  ┊ GC (min … max): 0.00% … 2.92%
#  Time  (median):     104.970 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   107.694 ms ±   9.677 ms  ┊ GC (mean ± σ):  0.61% ± 1.75%
#
#      ▄▃█▆▆▃  ▁▃▁ ▁     ▄   ▃
#   ▄▄▁██████▇▇███▇█▁▁▇▇▄█▁▇▁█▄▄▁▄▁▁▄▁▁▄▁▄▆▁▄▁▁▄▁▁▁▁▁▁▄▁▁▁▁▁▁▁▁▁▄ ▄
#   95.6 ms          Histogram: frequency by time          143 ms <
#
#  Memory estimate: 7.01 MiB, allocs estimate: 33.

# %% [markdown]
# Veremos ahora ejemplos con TV regularization en Julia

# %%
# Deconvolución iterativa de Richardson-Lucy con regularizador
optim_res = richardson_lucy_iterative(img_n, psf, λ=0.05, regularizer=TV(), iterations=30)
d1 = @benchmark richardson_lucy_iterative(img_n, psf, λ=0.05, regularizer=TV(), iterations=30) samples=100 evals=1 seconds=60
# Out:
# BenchmarkTools.Trial: 70 samples with 1 evaluation.
#  Range (min … max):  782.701 ms …   1.004 s  ┊ GC (min … max): 1.55% … 2.35%
#  Time  (median):     848.621 ms              ┊ GC (median):    1.71%
#  Time  (mean ± σ):   851.957 ms ± 45.815 ms  ┊ GC (mean ± σ):  1.80% ± 0.51%
#
#        ▂  ▂  ▂       ▂   ▂▅    █
#   ▅▅█▁▅█████▅███▁▁▁████▅▅██▅██▁██▁█▅▁▁▁▅▁▅▁▅▅▁▅▅▅▁▁▅▅▁▅▁▁▁▁▁▁▅ ▁
#   783 ms          Histogram: frequency by time          964 ms <
#
#  Memory estimate: 76.56 MiB, allocs estimate: 633694.

# %%
# Deconvolución iterativa de Richardson-Lucy con regularizador (optimizada)
tv = TV()
# Out:
# #677 (generic function with 1 method)

# %%
d2 = @benchmark richardson_lucy_iterative(img_n, psf, λ=0.05, regularizer=tv, iterations=30) samples=100 evals=1 seconds=60
# Out:
# BenchmarkTools.Trial: 100 samples with 1 evaluation.
#  Range (min … max):  134.956 ms … 175.986 ms  ┊ GC (min … max): 0.00% … 1.99%
#  Time  (median):     146.323 ms               ┊ GC (median):    1.73%
#  Time  (mean ± σ):   149.476 ms ±  10.207 ms  ┊ GC (mean ± σ):  1.42% ± 1.15%
#
#    ▁        ▁     █▃
#   ▇█▄▆▁▆▆▇▇▆█▇▄▆▇▇██▆▆▇▇▇▆▄▁▄▁▄▄▆▄▆▆▁▇▄▆▆▄▁▄▄▄▆▁▁▁▄▄▁▄▁▁▁▁▁▆▆▁▄ ▄
#   135 ms           Histogram: frequency by time          175 ms <
#
#  Memory estimate: 38.04 MiB, allocs estimate: 1057.

# %%
Gray.([img img_n optim_res])
# Out:
# 512×1536 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000393947)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000412309)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000409042)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000371891)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.00029953)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000209923)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.00013328)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(8.31266f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(5.55223f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.24735f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(3.83088f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.03869f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.81296f-5)
#  ⋮                                       ⋱  ⋮
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(7.49028f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(6.75136f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(9.4106f-7)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(1.8169f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.18663f-6)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(1.00105f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(2.24908f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(4.52535f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(8.10013f-5)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.000130222)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.000187881)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.00043638)

# %% [markdown]
# ---
# ## Cell
# Test usando solo el plano central del `cells3D` dataset

# %%
img = load("cells3d_convolved.tif")
img = Float32.(img)

psf = load("cells3d_psf.tif")
psf = Float32.(psf);

Gray.(psf/maximum(psf))
# Out:
# 256×256 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱  ⋮
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)

# %%
ipsf = ifftshift(psf);

# %%
deconvolved = richardson_lucy_iterative(img, ipsf; regularizer=nothing, iterations=30);

# %%
 c = @benchmark richardson_lucy_iterative(img, ipsf; regularizer=nothing, iterations=30) samples=100 evals=1 seconds=60
# Out:
# BenchmarkTools.Trial: 100 samples with 1 evaluation.
#  Range (min … max):  25.448 ms … 41.880 ms  ┊ GC (min … max): 0.00% … 32.61%
#  Time  (median):     26.656 ms              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   27.384 ms ±  2.397 ms  ┊ GC (mean ± σ):  0.95% ±  4.52%
#
#    ▁ █▇▁ ▁
#   ▄█▆███▇██▄▄▅▃▃▃▁▄▁▁▁▁▁▄▁▁▃▁▁▁▁▁▃▁▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃ ▃
#   25.4 ms         Histogram: frequency by time        39.5 ms <
#
#  Memory estimate: 1.76 MiB, allocs estimate: 33.

# %%
Gray.([img/maximum(img) deconvolved/maximum(deconvolved)])
# Out:
# 256×512 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.139208)   …  Gray{Float32}(0.15018)
#  Gray{Float32}(0.136976)      Gray{Float32}(0.321883)
#  Gray{Float32}(0.133411)      Gray{Float32}(0.329326)
#  Gray{Float32}(0.129447)      Gray{Float32}(0.201195)
#  Gray{Float32}(0.125544)      Gray{Float32}(0.117207)
#  Gray{Float32}(0.121956)   …  Gray{Float32}(0.0870524)
#  Gray{Float32}(0.118964)      Gray{Float32}(0.0819661)
#  Gray{Float32}(0.116711)      Gray{Float32}(0.084371)
#  Gray{Float32}(0.115105)      Gray{Float32}(0.0843237)
#  Gray{Float32}(0.114073)      Gray{Float32}(0.0796114)
#  Gray{Float32}(0.113758)   …  Gray{Float32}(0.0739567)
#  Gray{Float32}(0.114281)      Gray{Float32}(0.0714523)
#  Gray{Float32}(0.115386)      Gray{Float32}(0.0739858)
#  ⋮                         ⋱
#  Gray{Float32}(0.0760711)     Gray{Float32}(0.0973677)
#  Gray{Float32}(0.075697)   …  Gray{Float32}(0.0783323)
#  Gray{Float32}(0.0739218)     Gray{Float32}(0.0672488)
#  Gray{Float32}(0.0710568)     Gray{Float32}(0.0637309)
#  Gray{Float32}(0.0679526)     Gray{Float32}(0.0682716)
#  Gray{Float32}(0.0656165)     Gray{Float32}(0.0801718)
#  Gray{Float32}(0.0647187)  …  Gray{Float32}(0.0895341)
#  Gray{Float32}(0.0652603)     Gray{Float32}(0.076377)
#  Gray{Float32}(0.0666313)     Gray{Float32}(0.0454643)
#  Gray{Float32}(0.0680683)     Gray{Float32}(0.0251139)
#  Gray{Float32}(0.0691004)     Gray{Float32}(0.0231394)
#  Gray{Float32}(0.069607)   …  Gray{Float32}(0.0484152)
